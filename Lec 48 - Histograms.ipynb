# %%
# Let's begin by importing what we'll need (You'll probably be copying and pasting this a lot)

# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats librayr from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %% [markdown]
# First of all, source of information for what a histogram actually is:
# http://en.wikipedia.org/wiki/Histogram

# %%
#Create a random normal-dist dataset
dataset1 = randn(100)

#Plot a histogram of the dataset, note bins=10 by default
plt.hist(dataset1)
# Out:
# (array([ 3.,  6., 13., 11., 21., 19., 14., 10.,  2.,  1.]),
#  array([-2.41841876, -1.88252525, -1.34663174, -0.81073824, -0.27484473,
#          0.26104878,  0.79694229,  1.33283579,  1.8687293 ,  2.40462281,
#          2.94051632]),
#  <BarContainer object of 10 artists>)

# %%
# Lets make another dataset
dataset2 = randn(80)

#Plot
plt.hist(dataset2,color='indianred')
# Out:
# (array([ 2.,  0.,  5., 18., 21., 14., 13.,  5.,  1.,  1.]),
#  array([-2.85894787, -2.30112151, -1.74329514, -1.18546878, -0.62764242,
#         -0.06981605,  0.48801031,  1.04583668,  1.60366304,  2.1614894 ,
#          2.71931577]),
#  <BarContainer object of 10 artists>)

# %%
# We can use normed to plot on same plot

# Set normed=True for the plots to be normalized in order to comapre data sets with different number of observations
# Set alpha=0.5 for transperancy

plt.hist(dataset1,density=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)
# Out:
# (array([0.04481681, 0.04481681, 0.        , 0.        , 0.17926725,
#         0.04481681, 0.44816813, 0.35853451, 0.35853451, 0.58261857,
#         0.26890088, 0.35853451, 0.26890088, 0.31371769, 0.17926725,
#         0.04481681, 0.        , 0.04481681, 0.        , 0.04481681]),
#  array([-2.85894787, -2.58003469, -2.30112151, -2.02220832, -1.74329514,
#         -1.46438196, -1.18546878, -0.9065556 , -0.62764242, -0.34872923,
#         -0.06981605,  0.20909713,  0.48801031,  0.76692349,  1.04583668,
#          1.32474986,  1.60366304,  1.88257622,  2.1614894 ,  2.44040259,
#          2.71931577]),
#  <BarContainer object of 20 artists>)

# %%
# Make two more random normal dist data sets
data1 = randn(1000)
data2 = randn(1000)

#Can represent joint distributions using joint plots
sns.jointplot(x=data1,y=data2)

# %%
# Can also use hex bins for a more concise picture
sns.jointplot(x=data1,y=data2,kind="hex")

# %%
# Next we'll learn how to use Kernel Estimation Plots
