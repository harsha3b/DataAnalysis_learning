# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
#Now we'll learn DataFrames

#Let's get some data to play with. How about the NFL?
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
#Copy and read to get data
nfl_frame = pd.read_clipboard()

# %%
#Show
nfl_frame
# Out:
#    Rank                    Team     GP  Won  Lost  Tied   Pct.  \
# 0     1          Dallas Cowboys    964  550   408     6  0.574
# 1     2       Green Bay Packers  1,418  790   590    38  0.571
# 2     3        Baltimore Ravens    434  243   190     1  0.561
# 3     4    New England Patriots    966  537   420     9  0.561
# 4     5           Chicago Bears  1,452  786   624    42  0.556
# 5     6          Miami Dolphins    882  485   393     4  0.552
# 6     7       Minnesota Vikings    952  516   425    11  0.548
# 7     8      Kansas City Chiefs    966  521   433    12  0.546
# 8     9  San Francisco 49ers[b]  1,084  574   496    14  0.536
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1960   AFC East
# 4              1920  NFC North
# 5              1966   AFC East
# 6              1961  NFC North
# 7              1960   AFC West
# 8              1950    NFC Wes

# %%
# We can grab the oclumn names with .columns
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division'],
#       dtype='object')

# %%
#Lets see some specific data columns
DataFrame(nfl_frame,columns=['Team','Won','GP'])
# Out:
#                      Team  Won     GP
# 0          Dallas Cowboys  550    964
# 1       Green Bay Packers  790  1,418
# 2        Baltimore Ravens  243    434
# 3    New England Patriots  537    966
# 4           Chicago Bears  786  1,452
# 5          Miami Dolphins  485    882
# 6       Minnesota Vikings  516    952
# 7      Kansas City Chiefs  521    966
# 8  San Francisco 49ers[b]  574  1,084

# %%
nfl_frame.head()
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1960   AFC East
# 4              1920  NFC North

# %%
nfl_frame.tail()
# Out:
#    Rank                    Team     GP  Won  Lost  Tied   Pct.  \
# 4     5           Chicago Bears  1,452  786   624    42  0.556
# 5     6          Miami Dolphins    882  485   393     4  0.552
# 6     7       Minnesota Vikings    952  516   425    11  0.548
# 7     8      Kansas City Chiefs    966  521   433    12  0.546
# 8     9  San Francisco 49ers[b]  1,084  574   496    14  0.536
#
#    First NFL season   Division
# 4              1920  NFC North
# 5              1966   AFC East
# 6              1961  NFC North
# 7              1960   AFC West
# 8              1950    NFC Wes

# %%
#What happens if we ask for a column that doesn't exist?
DataFrame(nfl_frame,columns=['Team','First NFL season','GP','Stadium'])
# Out:
#                      Team  First NFL season     GP  Stadium
# 0          Dallas Cowboys              1960    964      NaN
# 1       Green Bay Packers              1921  1,418      NaN
# 2        Baltimore Ravens              1996    434      NaN
# 3    New England Patriots              1960    966      NaN
# 4           Chicago Bears              1920  1,452      NaN
# 5          Miami Dolphins              1966    882      NaN
# 6       Minnesota Vikings              1961    952      NaN
# 7      Kansas City Chiefs              1960    966      NaN
# 8  San Francisco 49ers[b]              1950  1,084      NaN

# %%
# Call columns
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division'],
#       dtype='object')

# %%
#We can retrieve individual columns
nfl_frame.Team
# Out:
# 0            Dallas Cowboys
# 1         Green Bay Packers
# 2          Baltimore Ravens
# 3      New England Patriots
# 4             Chicago Bears
# 5            Miami Dolphins
# 6         Minnesota Vikings
# 7        Kansas City Chiefs
# 8    San Francisco 49ers[b]
# Name: Team, dtype: object

# %%
# Or try this method for multiple word columns
nfl_frame['GP']
# Out:
# 0      964
# 1    1,418
# 2      434
# 3      966
# 4    1,452
# 5      882
# 6      952
# 7      966
# 8    1,084
# Name: GP, dtype: object

# %%
#We can retrieve rows through indexing
nfl_frame.loc[3]
# Out:
# Rank                                   4
# Team                New England Patriots
# GP                                   966
# Won                                  537
# Lost                                 420
# Tied                                   9
# Pct.                               0.561
# First NFL season                    1960
# Division                        AFC East
# Name: 3, dtype: object

# %%
#We can also assign value sto entire columns
nfl_frame['Stadium']="Levi's Stadium" #Careful with the ' here

# %%
nfl_frame
# Out:
#    Rank                    Team     GP  Won  Lost  Tied   Pct.  \
# 0     1          Dallas Cowboys    964  550   408     6  0.574
# 1     2       Green Bay Packers  1,418  790   590    38  0.571
# 2     3        Baltimore Ravens    434  243   190     1  0.561
# 3     4    New England Patriots    966  537   420     9  0.561
# 4     5           Chicago Bears  1,452  786   624    42  0.556
# 5     6          Miami Dolphins    882  485   393     4  0.552
# 6     7       Minnesota Vikings    952  516   425    11  0.548
# 7     8      Kansas City Chiefs    966  521   433    12  0.546
# 8     9  San Francisco 49ers[b]  1,084  574   496    14  0.536
#
#    First NFL season   Division         Stadium
# 0              1960   NFC East  Levi's Stadium
# 1              1921  NFC North  Levi's Stadium
# 2              1996  AFC North  Levi's Stadium
# 3              1960   AFC East  Levi's Stadium
# 4              1920  NFC North  Levi's Stadium
# 5              1966   AFC East  Levi's Stadium
# 6              1961  NFC North  Levi's Stadium
# 7              1960   AFC West  Levi's Stadium
# 8              1950    NFC Wes  Levi's Stadium

# %%
#Putting numbers for stadiums
nfl_frame["Stadium"] = np.arange(9)

#Show
nfl_frame
# Out:
#    Rank                    Team     GP  Won  Lost  Tied   Pct.  \
# 0     1          Dallas Cowboys    964  550   408     6  0.574
# 1     2       Green Bay Packers  1,418  790   590    38  0.571
# 2     3        Baltimore Ravens    434  243   190     1  0.561
# 3     4    New England Patriots    966  537   420     9  0.561
# 4     5           Chicago Bears  1,452  786   624    42  0.556
# 5     6          Miami Dolphins    882  485   393     4  0.552
# 6     7       Minnesota Vikings    952  516   425    11  0.548
# 7     8      Kansas City Chiefs    966  521   433    12  0.546
# 8     9  San Francisco 49ers[b]  1,084  574   496    14  0.536
#
#    First NFL season   Division  Stadium
# 0              1960   NFC East        0
# 1              1921  NFC North        1
# 2              1996  AFC North        2
# 3              1960   AFC East        3
# 4              1920  NFC North        4
# 5              1966   AFC East        5
# 6              1961  NFC North        6
# 7              1960   AFC West        7
# 8              1950    NFC Wes        8

# %%
# Call columns
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division', 'Stadium'],
#       dtype='object')

# %%
#Adding a Series to a DataFrame
stadiums = Series(["Levi's Stadium","AT&T Stadium","T mobile arena"],index=[4,0,8])

# %%
#Now input into the nfl DataFrame
nfl_frame['Stadium']=stadiums

#Show
nfl_frame
# Out:
#    Rank                    Team     GP  Won  Lost  Tied   Pct.  \
# 0     1          Dallas Cowboys    964  550   408     6  0.574
# 1     2       Green Bay Packers  1,418  790   590    38  0.571
# 2     3        Baltimore Ravens    434  243   190     1  0.561
# 3     4    New England Patriots    966  537   420     9  0.561
# 4     5           Chicago Bears  1,452  786   624    42  0.556
# 5     6          Miami Dolphins    882  485   393     4  0.552
# 6     7       Minnesota Vikings    952  516   425    11  0.548
# 7     8      Kansas City Chiefs    966  521   433    12  0.546
# 8     9  San Francisco 49ers[b]  1,084  574   496    14  0.536
#
#    First NFL season   Division         Stadium
# 0              1960   NFC East    AT&T Stadium
# 1              1921  NFC North             NaN
# 2              1996  AFC North             NaN
# 3              1960   AFC East             NaN
# 4              1920  NFC North  Levi's Stadium
# 5              1966   AFC East             NaN
# 6              1961  NFC North             NaN
# 7              1960   AFC West             NaN
# 8              1950    NFC Wes  T mobile arena

# %%
#We can also delete columns
del nfl_frame['Stadium']

nfl_frame
# Out:
#    Rank                    Team     GP  Won  Lost  Tied   Pct.  \
# 0     1          Dallas Cowboys    964  550   408     6  0.574
# 1     2       Green Bay Packers  1,418  790   590    38  0.571
# 2     3        Baltimore Ravens    434  243   190     1  0.561
# 3     4    New England Patriots    966  537   420     9  0.561
# 4     5           Chicago Bears  1,452  786   624    42  0.556
# 5     6          Miami Dolphins    882  485   393     4  0.552
# 6     7       Minnesota Vikings    952  516   425    11  0.548
# 7     8      Kansas City Chiefs    966  521   433    12  0.546
# 8     9  San Francisco 49ers[b]  1,084  574   496    14  0.536
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1960   AFC East
# 4              1920  NFC North
# 5              1966   AFC East
# 6              1961  NFC North
# 7              1960   AFC West
# 8              1950    NFC Wes

# %%
#DataFrames can be constructed many ways. Another way is from a dictionary of equal length lists
data = {'City':['SF','LA','NYC'],
        'Population':[837000,3880000,8400000]}

city_frame = DataFrame(data)

#Show
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
#For full list of ways to create DataFrames from various sources go to teh documentation for pandas:
website = 'http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True
